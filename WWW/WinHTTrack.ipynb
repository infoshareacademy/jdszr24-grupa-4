# %% [markdown]
# Wersja instalacyjna WinHTTrack wg. https://www.httrack.com/page/2/
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Lustro strony wykonało się z błędami
#
# Te dwa brakujące pliki to:
#
# wp-content/plugins/uicore-animate/assets/js/scroll-timeline.js
#
# wp-content/img/select-arrow.svg [user]
#
# Co to znaczy
# Pierwszy błąd dotyczy zasobu pluginu WordPress uicore-animate, a drugi pliku SVG wskazywanego z wygenerowanego CSS uicore-global.css. To bardzo typowy przypadek: strona lub plugin odwołuje się do pliku, którego faktycznie nie ma na serwerze albo ścieżka w CSS/HTML jest błędna.
#
# Ponieważ HTTrack pobrał resztę witryny poprawnie, te dwa 404 nie przekreślają kopii. Najczęściej skutkiem będzie brak jednego efektu animacji i ewentualnie brak ikonki strzałki w jakimś elemencie formularza/selecta.

# %% [markdown]
# ## Co dalej zrobić:
# Najpierw otwórz lokalną kopię w VS Code i sprawdź wizualnie:
#
# czy strona się ładuje,
#
# czy layout się nie rozsypuje,
#
# czy nie brakuje animacji lub ikon/selectów,
#
# czy konsola przeglądarki pokazuje tylko te dwa brakujące pliki.
#
# Jeśli wszystko działa poza drobiazgami, możesz spokojnie pracować dalej na tej kopii. Dwa błędy 404 przy 171 zapisanych plikach to raczej brakujące assety, a nie nieudane mirrorowanie całej strony.
#
# Jak naprawić lokalnie
# Najprostsza opcja to usunąć lub podmienić odwołania do brakujących zasobów w lokalnej kopii:
#
# znajdź w plikach odwołania do scroll-timeline.js,
#
# znajdź w CSS odwołanie do select-arrow.svg,
#
# usuń te linki albo podstaw własne pliki lokalne.
#
# Praktycznie:
#
# W VS Code użyj globalnego wyszukiwania Ctrl+Shift+F.
#
# Szukaj: scroll-timeline.js
#
# Szukaj: select-arrow.svg
#
# Zakomentuj import/skrypt albo zmień ścieżkę na lokalny zamiennik.
#
# Konkretna interpretacja
# scroll-timeline.js wygląda jak opcjonalny skrypt do animacji przewijania, więc jego brak zwykle nie blokuje działania całej strony. W najgorszym razie część efektów scroll/animate nie zadziała lokalnie.
#
# select-arrow.svg to z kolei brzmi jak dekoracyjny asset interfejsu, najpewniej strzałka w polu wyboru. Jeśli go nie ma, formularz nadal może działać, tylko bez jednej warstwy wizualnej.
#
# Dalsza praca w repo
# Możesz już zrobić pierwszy commit jako snapshot pobranego mirroru, bo kopia jest praktycznie kompletna. Potem w drugim commicie poprawisz lokalnie brakujące assety albo usuniesz ich referencje.

# %% [markdown]
# ### Polecenia:

# %%
cd C:\1\T4\jdszr24-grupa-4
git add WWW\czat_T4_1
git commit -m "Initial mirrored site from HTTrack"

# %% [markdown]
# ### A potem po poprawkach:

# %%
git add WWW\czat_T4_1
git commit -m "Fix missing asset references after mirror"

# %% [markdown]
# ### Najbardziej sensowny następny krok: nie powtarzać mirroru, tylko przejść do analizy lokalnych plików i naprawienia tych dwóch brakujących referencji.
